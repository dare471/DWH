# %% [markdown]
# # SUBSIDIES
# This is a scraper for subsidy applications in a platform [QOLDAU](https://subsidies.qoldau.kz/ru/subsidies/).
# There're 3 categories:
#   - Pesticides(since 2020, before was only herbicides)
#   - Seeds
#   - Fertilizers

# %%
# LIBRARIES
# *********
# request for the web page
import requests

# handle while requesting for the web page
from requests.packages.urllib3.exceptions import InsecureRequestWarning

# create a simulation of the pseudo-user
from selenium import webdriver

# set sleep on web page on every click, handling nginx error
import time
import datetime

# to get web page soure
from bs4 import BeautifulSoup

# create df
import pandas as pd 

# manipulate with shape of the df
import numpy as np

# record start time
from time import gmtime, strftime

# get rid off quotes
import csv

# %% [markdown]
# ### Links

# %%
# baseURL of Qoldau
baseUrl = "https://subsidies.qoldau.kz/ru/subsidies/"

# applications
appFerti = "fertilizer/pub-apps"
appPest = "herbicides/pub-apps"
appSeed = "seed/pub-apps"

appFerti_2019 = "fertilizer/pub-apps?Year=2019"
appPest_2019 = "herbicides/pub-apps?Year=2019"

# dicts of prods
sprPest = "herbicides/refs/usage-norms"
sprSeed = "seed/seeds"

listOfLinks = [appSeed, appPest, appFerti, appPest_2019 , appFerti_2019, sprSeed] #  , sprSeed, sprPest  
listOfNames =  ["Семена2019_2020", "Пестициды", "Удобрения", "Пестициды2019", "Удобрения2019", "СправочникСемян"] #,  , 'спрСемена', 'спрПестициды'

# %% [markdown]
# ### Memory usage counter

# %%
import tracemalloc
tracemalloc.start()
# my_complex_analysis_method()
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
tracemalloc.stop()
# Out:
# Current memory usage is 0.000541MB; Peak was 0.011006MB

# %% [markdown]
# ### Scraper

# %%
tracemalloc.start() ##############################

options = webdriver.ChromeOptions() 
options.add_argument("start-maximized")
options.add_argument('disable-infobars')
d = webdriver.Chrome(chrome_options=options, executable_path=r'C:\Program Files (x86)\chromedriver.exe')
baseUrl = baseUrl
allLinks = listOfLinks 
names = listOfNames   
allData = []
linkN = 0
current, peak = tracemalloc.get_traced_memory() ##############################
for link in allLinks:
    print(linkN, " = ", names[linkN])
    print("Started: ", datetime.datetime.now().astimezone().strftime("%Y-%m-%d, %H:%M:%S"))
    d.get(baseUrl+link)
    time.sleep(2)
    html = d.page_source
    nPages = int(d.find_elements_by_xpath('//li[@data-page-index]/a')[-2].text)
    print("This page's Navgation steps = ", nPages)
    tempLastN = []
    tempRowData = []
    cols = d.find_element_by_xpath("//div[@class='sw-result-table-container']/div/div/table").find_elements_by_tag_name('th')
    colNames = []
    tempColNames = []
    for col in cols:
        r = col.get_attribute("innerText").replace('\n', ',')
        time.sleep(1)
        tempColNames.append(r)
    colN = len(tempColNames)
    print(colN)
    print(tempColNames)
    for LastN in d.find_elements_by_xpath("//div[@class='pull-right']/div/span"):
        tempLastN.append(LastN.text.split(' '))
    lastN = int(tempLastN[-1][-1])
    for click in range(nPages):
        rows = d.find_element_by_xpath("//div[@class='sw-result-table-container']/div/div/table/tbody").find_elements_by_tag_name('td')
        if(rows[0].text != "Нет записей"):
            for row in rows:
                tempRowData.append(row.text)
            d.find_elements_by_xpath('//li[@data-page-index]/a')[-1].click()
            html = d.page_source
            s = BeautifulSoup(html, 'html.parser')
        count = 0
        testData = np.reshape(tempRowData, (-1, colN))
    f = pd.DataFrame(testData, columns=tempColNames)
    f.to_csv(r'C:\Users\Admin\Documents\qldData\/' + names[linkN] + '.csv', encoding='utf-8', sep='|')#, quoting = csv.QUOTE_NONE, escapechar = '')
    f.to_csv(r'\\aafssrv\SHARED-BI\files_aa_dwh_x\dataBase\/' + names[linkN] + '.csv', encoding='utf-8', sep='|')#, quoting = csv.QUOTE_NONE, escapechar = '')
    linkN += 1
    tempRowData = []
    print("Finished: ", datetime.datetime.now().astimezone().strftime("%Y-%m-%d, %H:%M:%S"))
    print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
# Out:
# <ipython-input-37-413861bded8a>:6: DeprecationWarning: use options instead of chrome_options
#   d = webdriver.Chrome(chrome_options=options, executable_path=r'C:\Program Files (x86)\chromedriver.exe')
# 0  =  Семена2019_2020
# Started:  2020-11-16, 17:51:24
# This page's Navgation steps =  698
# 16
# ['№', 'Область', 'Дата подачи заявки', 'Наименование заявителя', 'Поставщик семян', 'Наименование', 'Объем семян в базовой ед.измерения', 'Базовая единица измерения', 'Площадь использования, га', 'Статус', 'Тип заявки', 'Дата принятия заявки', 'Дата отклонения', 'Сумма субсидий (расчетная), тг.', 'Примечание к отрицательному решению', 'Причина отклонения']
# Finished:  2020-11-16, 20:12:50
# Current memory usage is 0.183435MB; Peak was 0.194117MB
# 1  =  Пестициды
# Started:  2020-11-16, 20:12:50
# This page's Navgation steps =  1676
# 16
# ['№', 'Область', 'Дата подачи заявки', 'Наименование заявителя', 'Производитель пестицидов', 'Наименование препарата', 'Объем пестицида в базовой ед.измерения', 'Базовая единица измерения', 'Площадь использования, га', 'Статус', 'Тип заявки', 'Дата принятия заявки', 'Дата отклонения', 'Сумма субсидий (расчетная), тг.', 'Причина отклонения', 'Примечание к отрицательному решению']

# %%
    print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")

# %% [markdown]
# ### Altering csv files
# need to replace path
# **`q.to_csv(r'C:\Users\M_MUKHANOVA\Desktop\Mini PowerBI\Satellite\qoldauData\q2020.csv', encoding='utf-8', sep='|', quoting = csv.QUOTE_NONE, escapechar = '')`**

# %%
# baseColNames  = ['Область', 'ДатаПодачиЗаявки', 'Заявитель',
#                  'Поставщик', 'Продукт',
#                  'Объем', 'БазоваяЕдиницаИзмерения',
#                  'ПлощадьИспользованияГа', 'Статус', 'ТипЗаявки',
#                  'ДатаПринятияЗаявки', 'ДатаОтклонения',
#                  'СуммаСубсидийТг', 'ПричинаОтклонения',
#                  'ПримечаниеКОтрицательномуРешению', 'group', 'year']
      
      

baseColNames  = ['region', 'appDate', 'applicant',
                 'provider', 'product',
                 'volume', 'unit',
                 'areaOfUsage', 'status', 'typeOfApp',
                 'AppAcceptanceDate', 'DateOfRejection',
                 'subsidies', 'reasonOfRejection',
                 'NoteOnNegativeResolution', 'group', 'year']


#---------------------------------------------------------------------------------
baseColNamesReorderForFerti = ['Область', 'Дата подачи заявки', 'Наименование заявителя',
                        'Производитель удобрений', 'Наименование удобрения', 
                        'Объем удобрения', 'Единица измерения',
                        'Площадь использования, га', 'Статус', 'Тип заявки',
                        'Дата принятия заявки', 'Дата отрицательного решения', 
                        'Сумма субсидий (расчетная), тг.', 'Причина отрицательного решения',
                        'Примечание к отрицательному решению', 'group', 'year']

#---------------------------------------------------------------------------------
baseColNamesReorderForSeeds = ['Область', 'Дата подачи заявки', 'Наименование заявителя',
                        'Поставщик семян', 'Наименование', 'Объем семян в базовой ед.измерения',
                        'Базовая единица измерения', 'Площадь использования, га', 'Статус',
                        'Тип заявки', 'Дата принятия заявки', 'Дата отклонения',
                        'Сумма субсидий (расчетная), тг.', 'Причина отклонения',
                        'Примечание к отрицательному решению', 'group']

# %%
#------------------------------------ P E S T I C I D E S ---------------------------------------
p20 =  pd.read_csv(r'C:\Users\Admin\Documents\qldData\Пестициды.csv', encoding='utf-8', sep='|')
p20['group'] = "Пестициды"
p20 = p20.iloc[:, 2:]
p20['year'] = "2020"
# print(p20.columns)
print(len(p20.columns))


p19 =  pd.read_csv(r'C:\Users\Admin\Documents\qldData\Пестициды2019.csv', encoding='utf-8', sep='|')
p19['group'] = "Пестициды"
p19 = p19.iloc[:, 2:]
p19['year'] = "2019"
# print(p19.columns)
print(len(p19.columns))


p = pd.concat([p19, p20], ignore_index = True)
p.columns = baseColNames

#------------------------------------ F E R T L I Z E R S ---------------------------------------

f20 =  pd.read_csv(r'C:\Users\Admin\Documents\qldData\Удобрения.csv', encoding='utf-8', sep='|')
f20['group'] = "Удобрения"
f20 = f20.iloc[:, 2:]
f20['year'] = "2020"

f19 =  pd.read_csv(r'C:\Users\Admin\Documents\qldData\Удобрения2019.csv', encoding='utf-8', sep='|')
f19['group'] = "Удобрения"
f19 = f19.iloc[:, 2:]
f19['year'] = "2019"

f = pd.concat([f19, f20], ignore_index = True)
f = f[baseColNamesReorderForFerti]
f.columns = baseColNames

#------------------------------------ S E E D S ------------------------------------------------
sAll =  pd.read_csv(r'C:\Users\Admin\Documents\qldData\Семена2019_2020.csv', encoding='utf-8', sep='|')
sAll['group'] = "Семена"
sAll = sAll.iloc[:, 2:]
sAll = sAll[baseColNamesReorderForSeeds]

s19 = sAll[sAll["Дата принятия заявки"].astype(str).str.contains("2019", case = False)]
s19['year'] = "2019"
s20 = sAll[sAll["Дата принятия заявки"].astype(str).str.contains("2020", case = False)]
s20['year'] = "2020"

s = pd.concat([s19, s20], ignore_index = True)
s.columns = baseColNames
#------------------------------------ A L L -- C A T E G O R I E S ------------------------------------------------
q = pd.concat([p, f, s], ignore_index = True)
q['applicantID'] =  q[['applicant', 'region']].agg('-'.join, axis=1)
q = q.replace(r'\n',' ', regex=True)

#------------------------------------ C O N S T R A C T I O N S ------------------------------------------------
colsToUpper = [0,2,3]
for colUpper in range(len(colsToUpper)):
    q.iloc[:, colsToUpper[colUpper]] = q.iloc[:, colsToUpper[colUpper]].str.upper()
q = q.replace(to_replace = ["ТОВАРИЩЕСТВА С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ", "ТОВАРИЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ",
                            'ЖАУАПКЕРШІЛІГІ ШЕКТЕУЛІ СЕРІКТЕСТІГІ'], 
              value = "ТОО",
              regex=True)
q = q.replace(to_replace = ["КРЕСТЬЯНСКОЕ ХОЗЯЙСТВА", "КРЕСТЬЯНСКОЕ ХОЗЯЙСТВО", "К/Х", "К\Х", "Ш/Қ", "Ш\Қ", 
                            "ШАРУА ҚОЖАЛЫҒЫ", "К.Х."], 
              value = "КХ",
              regex=True)
q = q.replace(to_replace = ["ФЕРМЕРСКОЕ ХОЗЯЙСТВО", "ФЕРМЕРСКОЕ ХОЗЯЙСТВО", "Ф/Х", "Ф\Х", "Ф/Қ", "Ф\Қ", 
                            "ФЕРМЕРЛІК ШАРУА ҚОЖАЛЫҒЫ", "Ф.Х."], 
              value = "ФХ",
              regex=True)
q = q.replace(to_replace = ["АКЦИОНЕРНОЕ ОБЩЕСТВО", "АКЦИОНЕРЛІК ҚОҒАМЫ"], 
              value = "АО",
              regex=True)
q = q.replace(to_replace = ["ӨНДІРІСТІК КООПЕРАТИВІ", "АУЫЛ ШАРУАШЫЛЫҒЫ ӨНДІРІСТІК КООПЕРАТИВІ",
                            "СЕЛЬСКОХОЗЯЙСТВЕННЫЙ ПРОИЗВОДСТВЕННЫЙ КООПЕРАТИВ", "ПРОИЗВОДСТВЕННЫЙ КООПЕРАТИВ"], 
              value = "СПК",
              regex=True)
q['applicant'] = q['applicant'].replace(to_replace = ['"', "'", '«', '»', '/', '\(', '\)'], 
              value = "", regex=True)
q['provider'] = q['provider'].replace(to_replace = ['"', "'", '«', '»', '/', '\(', '\)'], 
              value = "", regex=True)

#------------------------------------ D I S T R I B U T O R S ------------------------------------------------
pak = ['ТОО ПОЛГАР АГРОКЕМ', 'ТОО ПЕРВАЯ АГРОХИМИЧЕСКАЯ КОМПАНИЯ']
q['provider'].replace({pak[0]: 'ПАК', pak[1]: 'ПАК', 'ТОО ALEM AGRO TRADE': 'ALEM AGRO'}, inplace=True, regex=True)
q['provider'] = q['provider'].str.replace('ТОО ALEM AGRO HOLDING АЛЕМАГРО ХОЛДИНГ', 'ALEM AGRO')
#------------------------------------  A A   l o g i c a l  c o l u m n ------------------------------------------------- 
q['АА'] = np.where(q['provider'] == 'ALEM AGRO', 'Да', 'Нет')
aaClient = q[['АА', 'applicantID']].loc[q['АА'] == "Да"].drop_duplicates().reset_index().iloc[:,2:]
q['isSubsAaClient'] = q.applicantID.isin(aaClient.applicantID).astype(bool)

#------------------------------------ P A T H  ------------------------------------
q.to_csv(r'C:\Users\Admin\Documents\qldData\q.csv', encoding='utf-8', sep='|', quoting = csv.QUOTE_NONE, escapechar = '')
#------------------------------------ R A N D O M   5   R O W S ------------------------------------
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
q.sample(5)

# %% [markdown]
# ### Transpose & exporting final file to upload to the AA_DWH_X server

# %%
test = pd.melt(q.reset_index(), id_vars = ['index']).sort_values(by = ['index'])
import csv
test.to_csv(r"\\aafssrv\SHARED-BI\files_aa_dwh_x\testQoldau.csv", header = ['index1', 'variable', 'value'], encoding='utf-8', sep='|', quoting = csv.QUOTE_NONE, escapechar = '')
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")

# %% [markdown]
# ### STOP tracemalloc

# %%
tracemalloc.stop()

# %% [markdown]
# # Checking data

# %%
test1 = test
test1.columns = ['index1', 'cols', 'vals']
test
# Out:
#          index1                              cols  \
# 0             0                           Область
# 481392        0                         Поставщик
# 641856        0                           Продукт
# 802320        0                             Объем
# 962784        0           БазоваяЕдиницаИзмерения
# ...         ...                               ...
# 2406959  160463  ПримечаниеКОтрицательномуРешению
# 2567423  160463                         Категория
# 2727887  160463                       applicantID
# 1444175  160463                            Статус
# 3209279  160463       клиентПолучившийСубсЧерезАА
#
#                                                       vals
# 0                                      АКТЮБИНСКАЯ ОБЛАСТЬ
# 481392                               ТОО АКТОБЕ-АГРОСЕРВИС
# 641856                                      САРАТОВСКАЯ 42
# 802320                                           13 844,61
# 962784                                                  кг
# ...                                                    ...
# 2406959  В соответствии подпункта 1) п. 12 Правил субси...
# 2567423                                          Пестициды
# 2727887               КХ Отегенов Е.К.-Акмолинская область
# 1444175                              Отрицательное решение
# 3209279                                              False
#
# [3209280 rows x 3 columns]

# %%
test.shape
# Out:
# (3209280, 3)

# %%
test1 = test1.pivot_table(index=['index1'], columns='cols', aggfunc= lambda x: x)
test1.columns = test1.columns.droplevel().rename(None)
test1
# Out:
#                                               applicantID   АА  \
# index1
# 0                    """ АКБАР "" КХ"-Актюбинская область  Нет
# 1       МИРЗАЛИЕВ КАРЖАУБАЙ ДОСИМОВИЧ-Туркестанская об...  Нет
# 2       МИРЗАЛИЕВ КАРЖАУБАЙ ДОСИМОВИЧ-Туркестанская об...  Нет
# 3       МИРЗАЛИЕВ КАРЖАУБАЙ ДОСИМОВИЧ-Туркестанская об...  Нет
# 4       МИРЗАЛИЕВ НУРЛИБЕК ЖАСУЗАКОВИЧ-Туркестанская о...  Нет
# ...                                                   ...  ...
# 160459                   ТОО "РЕАБВИ"-Акмолинская область  Нет
# 160460                      КХ "АЛҒА"-Актюбинская область  Нет
# 160461            ТОО "ПРИРЕЧЕНСКОЕ"-Костанайская область  Нет
# 160462             к/х "Алькен С.Т."-Костанайская область  Нет
# 160463               КХ Отегенов Е.К.-Акмолинская область  Нет
#
#        БазоваяЕдиницаИзмерения    ДатаОтклонения  ДатаПодачиЗаявки  \
# index1
# 0                           кг               NaN  28.11.2019 16:25
# 1                           кг               NaN  24.07.2019 10:56
# 2                           кг               NaN  21.05.2019 11:47
# 3                           кг               NaN  16.05.2019 11:15
# 4                         тонн               NaN  06.08.2019 21:05
# ...                        ...               ...               ...
# 160459                    литр               NaN  09.07.2020 16:32
# 160460                    литр               NaN  09.07.2020 16:32
# 160461                      кг               NaN  09.07.2020 16:32
# 160462                    литр               NaN  09.07.2020 16:32
# 160463                      кг  09.07.2020 18:52  09.07.2020 16:27
#
#        ДатаПринятияЗаявки                       Заявитель  Категория  \
# index1
# 0        29.11.2019 10:40                       АКБАР  КХ     Семена
# 1                     NaN   МИРЗАЛИЕВ КАРЖАУБАЙ ДОСИМОВИЧ  Удобрения
# 2                     NaN   МИРЗАЛИЕВ КАРЖАУБАЙ ДОСИМОВИЧ  Удобрения
# 3        28.05.2019 16:19   МИРЗАЛИЕВ КАРЖАУБАЙ ДОСИМОВИЧ  Удобрения
# 4        16.08.2019 16:00  МИРЗАЛИЕВ НУРЛИБЕК ЖАСУЗАКОВИЧ  Удобрения
# ...                   ...                             ...        ...
# 160459   09.07.2020 18:54                      ТОО РЕАБВИ  Пестициды
# 160460                NaN                         КХ АЛҒА  Пестициды
# 160461   07.09.2020 18:31                ТОО ПРИРЕЧЕНСКОЕ  Пестициды
# 160462   07.09.2020 18:29                  КХ АЛЬКЕН С.Т.  Пестициды
# 160463                NaN                КХ ОТЕГЕНОВ Е.К.  Пестициды
#
#                       Область      Объем ПлощадьИспользованияГа  \
# index1
# 0         АКТЮБИНСКАЯ ОБЛАСТЬ  13 844,61               1 064,97
# 1       ТУРКЕСТАНСКАЯ ОБЛАСТЬ   4 350,00                   8,70
# 2       ТУРКЕСТАНСКАЯ ОБЛАСТЬ   2 610,00                   8,70
# 3       ТУРКЕСТАНСКАЯ ОБЛАСТЬ   2 600,00                   8,70
# 4       ТУРКЕСТАНСКАЯ ОБЛАСТЬ       8,10                  20,05
# ...                       ...        ...                    ...
# 160459    АКМОЛИНСКАЯ ОБЛАСТЬ     200,00                  49,00
# 160460    АКТЮБИНСКАЯ ОБЛАСТЬ   1 000,00                 250,00
# 160461   КОСТАНАЙСКАЯ ОБЛАСТЬ     135,00              16 875,00
# 160462   КОСТАНАЙСКАЯ ОБЛАСТЬ     600,00               1 001,00
# 160463    АКМОЛИНСКАЯ ОБЛАСТЬ       4,00                 200,01
#
#                     Поставщик  \
# index1
# 0       ТОО АКТОБЕ-АГРОСЕРВИС
# 1                  ТОО КАЙНАР
# 2                  ТОО КАЙНАР
# 3                  АО КАЗАЗОТ
# 4                  АО КАЗАЗОТ
# ...                       ...
# 160459      ТОО ЕВРОГЕРБИЦИДЫ
# 160460  ТОО АКТОБЕ-АГРОСЕРВИС
# 160461        ТОО НЕРТУС АГРО
# 160462         ТОО АСТАНА-НАН
# 160463   ТОО AГРО-СЕРВИС-ШАНС
#
#                          ПримечаниеКОтрицательномуРешению  \
# index1
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 160459                                                NaN
# 160460                                                NaN
# 160461                                                NaN
# 160462                                                NaN
# 160463  В соответствии подпункта 1) п. 12 Правил субси...
#
#                                         ПричинаОтклонения  \
# index1
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 160459                                                NaN
# 160460                                                NaN
# 160461                                                NaN
# 160462                                                NaN
# 160463  установление недостоверности документов, предс...
#
#                                          Продукт       Сезон  \
# index1
# 0                                 САРАТОВСКАЯ 42  Сезон 2019
# 1                     Суперфосфат простой (P-15)  Сезон 2019
# 2                     Суперфосфат простой (P-15)  Сезон 2019
# 3                     Селитра аммиачная (N 34,4)  Сезон 2019
# 4                     Селитра аммиачная (N 34,4)  Сезон 2019
# ...                                          ...         ...
# 160459               ТОРНАДО 540, водный раствор  Сезон 2020
# 160460               ТОРНАДО 540, водный раствор  Сезон 2020
# 160461       СТРАЖ, водно-диспергируемые гранулы  Сезон 2020
# 160462      ЭФИР ЭКСТРА 905, концентрат эмульсии  Сезон 2020
# 160463  ФИНИТО 750, водно-диспергируемые гранулы  Сезон 2020
#
#                        Статус СуммаСубсидийТг  \
# index1
# 0             Заявка оплачена    1 176 791,00
# 1                Аннулирована       82 650,00
# 2                Аннулирована       61 987,50
# 3             Заявка оплачена       70 948,50
# 4             Заявка оплачена      283 500,00
# ...                       ...             ...
# 160459        Заявка оплачена       95 599,00
# 160460               Отозвана      609 718,75
# 160461        Заявка оплачена      949 218,75
# 160462        Заявка оплачена      493 500,00
# 160463  Отрицательное решение       51 040,00
#
#                                                 ТипЗаявки  \
# index1
# 0       Заявка на получение субсидий за фактически отп...
# 1                                              Переводная
# 2                                              Переводная
# 3                                              Переводная
# 4                                              Переводная
# ...                                                   ...
# 160459                                             Прямая
# 160460                                             Прямая
# 160461                                             Прямая
# 160462                                             Прямая
# 160463                                             Прямая
#
#        клиентПолучившийСубсЧерезАА
# index1
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 160459                       False
# 160460                       False
# 160461                       False
# 160462                       False
# 160463                       False
#
# [160464 rows x 20 columns]

# %%
test1.columns
# Out:
# Index(['applicantID', 'АА', 'БазоваяЕдиницаИзмерения', 'ДатаОтклонения',
#        'ДатаПодачиЗаявки', 'ДатаПринятияЗаявки', 'Заявитель', 'Категория',
#        'Область', 'Объем', 'ПлощадьИспользованияГа', 'Поставщик',
#        'ПримечаниеКОтрицательномуРешению', 'ПричинаОтклонения', 'Продукт',
#        'Сезон', 'Статус', 'СуммаСубсидийТг', 'ТипЗаявки',
#        'клиентПолучившийСубсЧерезАА'],
#       dtype='object')

# %%
statuses = test1['Статус'].unique()
statuses
# Out:
# array(['Заявка оплачена', 'Аннулирована', 'Отозвана',
#        'Отрицательное решение', 'Не оплачена казначейством',
#        'Заявка подана', 'Заявка у элитсемхоза', 'Сформирован платеж',
#        'Заявка к оплате', 'Заявка у производителя удобрений',
#        'Заявка у производителя СЗР'], dtype=object)

# %%
kost = test1[(test1['Область'] == 'КОСТАНАЙСКАЯ ОБЛАСТЬ') & (test1['Статус'] != 'Аннулирована') 
                                                          & (test1['Статус'] != 'Отозвана')
                                                          & (test1['Статус'] != 'Отрицательное решение') 
                                                          & (test1['Статус'] != 'Не оплачена казначейством')]
kost
# Out:
#                                            applicantID   АА  \
# index1
# 252             МИРЖИБАЕВ ЖАНИБЕК-Костанайская область  Нет
# 257             МИРЖИБАЕВ ЖАНИБЕК-Костанайская область  Нет
# 1349       МУХАМЕТЖАНОВА СВЕТЛАНА-Костанайская область  Нет
# 1454    Михнев Александр Павлович-Костанайская область  Нет
# 1463    Михнев Александр Павлович-Костанайская область  Нет
# ...                                                ...  ...
# 160446        БАБИЧ ИВАН ИВАНОВИЧ-Костанайская область  Нет
# 160449          к/х "Алькен С.Т."-Костанайская область  Нет
# 160451               ТОО "ТРОЯНА"-Костанайская область  Нет
# 160461         ТОО "ПРИРЕЧЕНСКОЕ"-Костанайская область  Нет
# 160462          к/х "Алькен С.Т."-Костанайская область  Нет
#
#        БазоваяЕдиницаИзмерения ДатаОтклонения  ДатаПодачиЗаявки  \
# index1
# 252                       литр            NaN  19.06.2019 11:53
# 257                       литр            NaN  17.06.2019 12:59
# 1349                      литр            NaN  07.07.2019 14:44
# 1454                      литр            NaN  17.06.2019 22:51
# 1463                      литр            NaN  17.06.2019 23:51
# ...                        ...            ...               ...
# 160446                    литр            NaN  09.07.2020 16:17
# 160449                    литр            NaN  09.07.2020 16:23
# 160451                    литр            NaN  09.07.2020 16:26
# 160461                      кг            NaN  09.07.2020 16:32
# 160462                    литр            NaN  09.07.2020 16:32
#
#        ДатаПринятияЗаявки                  Заявитель  Категория  \
# index1
# 252      20.06.2019 19:03          МИРЖИБАЕВ ЖАНИБЕК  Пестициды
# 257      18.06.2019 19:31          МИРЖИБАЕВ ЖАНИБЕК  Пестициды
# 1349     07.08.2019 09:45     МУХАМЕТЖАНОВА СВЕТЛАНА  Пестициды
# 1454     19.06.2019 08:52  МИХНЕВ АЛЕКСАНДР ПАВЛОВИЧ  Удобрения
# 1463     19.06.2019 08:54  МИХНЕВ АЛЕКСАНДР ПАВЛОВИЧ  Удобрения
# ...                   ...                        ...        ...
# 160446   07.09.2020 18:24        БАБИЧ ИВАН ИВАНОВИЧ  Пестициды
# 160449   07.09.2020 18:26             КХ АЛЬКЕН С.Т.  Пестициды
# 160451   07.09.2020 18:29                 ТОО ТРОЯНА  Пестициды
# 160461   07.09.2020 18:31           ТОО ПРИРЕЧЕНСКОЕ  Пестициды
# 160462   07.09.2020 18:29             КХ АЛЬКЕН С.Т.  Пестициды
#
#                      Область     Объем ПлощадьИспользованияГа  \
# index1
# 252     КОСТАНАЙСКАЯ ОБЛАСТЬ     40,00                  98,00
# 257     КОСТАНАЙСКАЯ ОБЛАСТЬ     30,00                  98,00
# 1349    КОСТАНАЙСКАЯ ОБЛАСТЬ    100,00                 245,00
# 1454    КОСТАНАЙСКАЯ ОБЛАСТЬ     45,00                  57,00
# 1463    КОСТАНАЙСКАЯ ОБЛАСТЬ     40,00                 332,00
# ...                      ...       ...                    ...
# 160446  КОСТАНАЙСКАЯ ОБЛАСТЬ    190,00                 293,86
# 160449  КОСТАНАЙСКАЯ ОБЛАСТЬ  3 000,00               1 475,00
# 160451  КОСТАНАЙСКАЯ ОБЛАСТЬ    500,00                 837,00
# 160461  КОСТАНАЙСКАЯ ОБЛАСТЬ    135,00              16 875,00
# 160462  КОСТАНАЙСКАЯ ОБЛАСТЬ    600,00               1 001,00
#
#                                      Поставщик  \
# index1
# 252                              ТОО ПЕСТИЦИДЫ
# 257                              ТОО ПЕСТИЦИДЫ
# 1349                             ТОО ПЕСТИЦИДЫ
# 1454    ТОО A.S.K. KAZAKHSTAN А.С.К. КАЗАХСТАН
# 1463    ТОО A.S.K. KAZAKHSTAN А.С.К. КАЗАХСТАН
# ...                                        ...
# 160446                  ТОО ЩЕЛКОВО АГРОХИМ-KZ
# 160449                          ТОО АСТАНА-НАН
# 160451                                     ПАК
# 160461                         ТОО НЕРТУС АГРО
# 160462                          ТОО АСТАНА-НАН
#
#        ПримечаниеКОтрицательномуРешению ПричинаОтклонения  \
# index1
# 252                                 NaN               NaN
# 257                                 NaN               NaN
# 1349                                NaN               NaN
# 1454                                NaN               NaN
# 1463                                NaN               NaN
# ...                                 ...               ...
# 160446                              NaN               NaN
# 160449                              NaN               NaN
# 160451                              NaN               NaN
# 160461                              NaN               NaN
# 160462                              NaN               NaN
#
#                                                   Продукт       Сезон  \
# index1
# 252                          СПАЙДЕР, концентрат эмульсии  Сезон 2019
# 257                              ТРЕЛ 300, водный раствор  Сезон 2019
# 1349                         СПАЙДЕР, концентрат эмульсии  Сезон 2019
# 1454           Фертигрейн Старт (FERTIGRAIN START) (N-3%)  Сезон 2019
# 1463    Текнофит РН (TECNOPHYT PH) (поли-гиброки-карбо...  Сезон 2019
# ...                                                   ...         ...
# 160446                ОВСЮГЕН ЭКСТРА, концентрат эмульсии  Сезон 2020
# 160449                              СМЕРЧ, водный раствор  Сезон 2020
# 160451                      ПРОГРЕСС, концентрат эмульсии  Сезон 2020
# 160461                СТРАЖ, водно-диспергируемые гранулы  Сезон 2020
# 160462               ЭФИР ЭКСТРА 905, концентрат эмульсии  Сезон 2020
#
#                  Статус СуммаСубсидийТг ТипЗаявки клиентПолучившийСубсЧерезАА
# index1
# 252     Заявка оплачена      186 200,00    Прямая                       False
# 257     Заявка оплачена      124 509,00    Прямая                       False
# 1349    Заявка оплачена      465 500,00    Прямая                       False
# 1454    Заявка оплачена       68 102,68    Прямая                       False
# 1463    Заявка оплачена       55 625,00    Прямая                       False
# ...                 ...             ...       ...                         ...
# 160446  Заявка оплачена      497 562,50    Прямая                       False
# 160449  Заявка оплачена    2 048 400,00    Прямая                       False
# 160451  Заявка оплачена      384 079,50    Прямая                        True
# 160461  Заявка оплачена      949 218,75    Прямая                       False
# 160462  Заявка оплачена      493 500,00    Прямая                       False
#
# [14370 rows x 20 columns]

# %%
kostSubs = kost[['СуммаСубсидийТг']].replace(',', '.', regex = True).replace(' ', '', regex = True)
mySum = kostSubs.astype(float).sum()
mySum
# Out:
# СуммаСубсидийТг    2.131157e+10
# dtype: float64
